# %%
### Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

# %matplotlib inline

# %%
### import the dataset 
df = pd.read_csv('dataset/car data.csv')

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
'''
Now lets explore the data a bit and check the null values , important features etc
Also by analysing the data we can decide which model to use.
'''
# Out:
# '\nNow lets explore the data a bit and check the null values , important features etc\nAlso by analysing the data we can decide which model to use.\n'

# %%
## Check missing values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
## Decribing the dataset 
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.shape
# Out:
# (301, 9)

# %%
## Checking the unique values in categorical columns
df.head(2)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0

# %%
list_1 = ['Seller_Type','Fuel_Type','Transmission']
for col in list_1 :
    print(df[col].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']

# %%
## Now lets convert the years col to no of years col 
## By doing this it will be easy to analyse and predict the results
## We also exclude the name col as is it is of no use 
final_df = df[1:]
final_df['no_of_year'] = 2020 - final_df['Year']
final_df.head()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
#
#   Seller_Type Transmission  Owner  no_of_year
# 1      Dealer       Manual      0           7
# 2      Dealer       Manual      0           3
# ...

# %%
### Drop the year column now it is no use
final_df.drop(['Year'],axis=1,inplace=True)
final_df.head()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 1            sx4           4.75           9.54       43000    Diesel
# 2           ciaz           7.25           9.85        6900    Petrol
# 3        wagon r           2.85           4.15        5200    Petrol
# 4          swift           4.60           6.87       42450    Diesel
# 5  vitara brezza           9.25           9.83        2071    Diesel
#
#   Seller_Type Transmission  Owner  no_of_year
# 1      Dealer       Manual      0           7
# 2      Dealer       Manual      0           3
# 3      Dealer       Manual      0           9
# 4      Dealer       Manual      0           6
# ...
